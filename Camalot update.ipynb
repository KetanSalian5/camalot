# %%
import camelot
import pandas as pd
import camelot
import matplotlib.pyplot as plt

# %%
tab=camelot.read_pdf('infosys-ar-22.pdf',pages='49,50',flavor='stream',split_text=True,edge_tol=300)
##table_areas=['100,499,566,100'] Note table_areas accept string of the from(x1,x2,y1,y2)
#Where (x1,y1)-> top-left and (x2,y2) -> bottom-right in PDF coordinate space.the bottom-left corner of the page is origin 
#with coordinates (0, 0)

# %%
tab[0],tab[1]
# Out:
# (<Table shape=(39, 15)>, <Table shape=(42, 15)>)

# %%
tab[0].parsing_report
# Out:
# {'accuracy': 99.28, 'whitespace': 47.86, 'order': 1, 'page': 49}

# %%
tab[1].parsing_report
# Out:
# {'accuracy': 99.65, 'whitespace': 45.71, 'order': 1, 'page': 50}

# %%
tab[0].df
# Out:
#        0                         1           2              3   \
# 0   (Purs  uant to first proviso to  sub-sectio  n (3) of Sect
# 1
# 2     Sl.               Name of the   Financial        Date of
# 3     No.                subsidiary      period    acquisition
# 4                                         ended
# 5
# 6
# 7       1               Infosys BPM     Mar 31,             NA
# 8                        Limited(2)        2022
# 9       2                 EdgeVerve     Mar 31,             NA
# 10                  Systems Limited        2022
# 11      3          Infosys McCamish     Dec 31,         Dec 4,
# 12                   Systems LLC(3)        2021           2009
# 13      4           Infy Consulting     Mar 31,             NA
# 14                   Company Ltd(4)        2022
# 15      5            Infosys Public     Mar 31,             NA
# 16               Services, Inc. USA        2022
# 17      6          Stater Nederland     Dec 31,             NA
# ...

# %%
tab[1].df
# Out:
#      0                        1        2            3          4        5   \
# 0   No.               subsidiary   period  acquisition  Reporting  capital
# 1                                   ended                currency
# 2
# 3
# 4    14       Infosys Consulting  Dec 31,           NA    1 EUR =       17
# 5                        GmbH(4)     2021                 ₹ 84.22
# 6    15        HIPUS Co., Ltd(7)  Mar 31,       Apr 1,    1 JPY =       32
# 7                                    2022         2019     ₹ 0.62
# 8    16               WongDoody,  Dec 31,           NA    1 USD =        1
# 9                     Inc(9)(10)     2021                 ₹ 74.34
# 10   17          Panaya Ltd.(11)  Dec 31,           NA    1 USD =      256
# 11                                   2021                 ₹ 74.34
# 12   18       Infosys Consulting  Dec 31,           NA    1 RON =       17
# 13              S.R.L. (Romania)     2021                 ₹ 17.01
# ...

# %%
tab.export('infosysnew.csv',f='csv',compress=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [92], in <cell line: 2>()
#       1 import cv2 as cv
# ----> 2 tab.export('infosysnew.csv',f='csv',compress=True)
#
# AttributeError: 'Table' object has no attribute 'export'

# %%
tab[0],tab[1]
# Out:
# (<Table shape=(36, 15)>, <Table shape=(42, 15)>)

# %%
camelot.plot(tab[1],kind='contour').show()
# Out:
# C:\Users\Ketan\AppData\Local\Temp\ipykernel_17504\3780137616.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tab[1],kind='contour').show()

# %%
tab=camelot.read_pdf('infosys-ar-22.pdf',pages='49',flavor='stream',)#,columns=['72,95,209,327,442,529,566,606,683'], split_text=True

# %%
tab[0].df
# Out:
#      0                    1        2            3          4        5   \
# 0   No.           subsidiary   period  acquisition  Reporting  capital
# 1                               ended                currency
# 2
# 3
# 4     1          Infosys BPM  Mar 31,           NA        INR       34
# 5                 Limited(2)     2022
# 6     2            EdgeVerve  Mar 31,           NA        INR    1,312
# 7            Systems Limited     2022
# 8     3     Infosys McCamish  Dec 31,       Dec 4,    1 USD =      175
# 9             Systems LLC(3)     2021         2009    ₹ 74.34
# 10    4      Infy Consulting  Mar 31,           NA    1 GBP =      135
# 11            Company Ltd(4)     2022                 ₹ 99.46
# 12    5       Infosys Public  Mar 31,           NA    1 USD =       98
# 13        Services, Inc. USA     2022                 ₹ 75.79
# 14    6     Stater Nederland  Dec 31,           NA    1 EUR =        8
# 15                   B.V.(5)     2021                 ₹ 84.22
# ...

# %%
tab=camelot.read_pdf('infosys-ar-22.pdf',pages='49',flavor='stream',columns=['72,95,209,327,442,529,566,606,683'], split_text=True,row_tol=20)

# %%
tab[0].df
# Out:
#       0                        1  \
# 0   No.                   subsid
# 1     1           Infosy\nLimite
# 2     2             EdgeV\nSyste
# 3     3                   Infosy
# 4     4            Syste\nInfy C
# 5     5             Comp\nInfosy
# 6     6           Servic\nStater
# 7     7             B.V.\nInfosy
# 8     8           z o.o.\nInfosy
# 9                  Techn\n(China
# 10    9            Outbo\nInc. d
# 11   10  (US)(6)\nInfosy\nPTE. L
# 12   11                   Infosy
# 13                  Techn\n(Shan
# 14   12             Comp\nInfosy
# 15                Techn\nR. L. d
# 16   13            Infosy\nand M
# 17                          GmbH
#
#                                                     2  \
# 0                        iary\nperiod \nacquis\nended
# 1                    s BPM \nMar 31, \nNA\nd(2)\n2022
# 2               erve \nMar 31, \nNA\nms Limited\n2022
# 3                        s McCamish \nDec 31, \nDec 4
# ...

# %%
tab.export('50inf.csv',f='csv',compress=True)

# %%
tab[0].to_csv('50inf.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 tab[0].to_csv('50inf.csv')
#
# File ~\anaconda3\lib\site-packages\camelot\core.py:579, in Table.to_csv(self, path, **kwargs)
#     577 kw = {"encoding": "utf-8", "index": False, "header": False, "quoting": 1}
#     578 kw.update(kwargs)
# --> 579 self.df.to_csv(path, **kw)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
# ...

# %%
pd.read_csv('50inf.csv')
# Out:
#      No.    subsid           iary\nperiod \nacquis ition\nReporting \ncapital  \
# 0    NaN       NaN                           ended                   currency
# 1    NaN       NaN                             NaN                        NaN
# 2    NaN       NaN                             NaN                        NaN
# 3    1.0    Infosy            s BPM \nMar 31, \nNA                   INR\n 34
# 4    NaN    Limite                      d(2)\n2022                        NaN
# 5    2.0     EdgeV             erve \nMar 31, \nNA                INR\n 1,312
# 6    NaN     Syste                ms Limited\n2022                        NaN
# 7    3.0    Infosy    s McCamish \nDec 31, \nDec 4         , \n1 USD = \n 175
# 8    NaN     Syste           ms LLC(3)\n2021\n2009                    ₹ 74.34
# 9    4.0    Infy C        onsulting \nMar 31, \nNA             1 GBP = \n 135
# 10   NaN      Comp                any Ltd(4)\n2022                    ₹ 99.46
# ...

# %%
import cv2 as cv
table = camelot.read_pdf("infosys-ar-22.pdf",pages="125",flavor='stream') #edge_tol=300)

# %%
table[0]
# Out:
# <Table shape=(27, 2)>

# %%
table[0].parsing_report
# Out:
# {'accuracy': 98.58, 'whitespace': 35.19, 'order': 1, 'page': 125}

# %%
#This kind us to 
camelot.plot(table[0],kind='contour').show()
# Out:
# C:\Users\Ketan\AppData\Local\Temp\ipykernel_17504\120413176.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(table[0],kind='contour').show()

# %%
table[0].df
# Out:
#                                                     0  \
# 0
# 1                                           Corporate
# 2   Infosys was incorporated in Pune, in 1981, as ...
# 3   Private Limited, a private limited company und...
# 4   Act, 1956. In 1983, the corporate headquarters...
# 5   to Bengaluru. The name of the Company was chan...
# 6   Infosys Technologies Private Limited in April ...
# 7   Technologies Limited in June 1992, when the Co...
# 8
# 9   public limited company. We made an initial pub...
# 10
# 11  in February 1993 and were listed on stock exch...
# 12
# 13  June 1993. Trading opened at ₹145 per share, c...
# 14
# 15  IPO price of ₹95 per share. In October 1994, w...
# 16  placement of 5,50,000 shares at ₹450 each to F...
# 17  Investors (FIIs), Financial Institutions (FIs)...
# 18
# 19  In March 1999, we issued 20,70,000 American De...
# 20
# 21  (ADSs) (equivalent to 10,35,000 equity shares ...
# 22
# 23  each) at US$ 34 per ADS under the ADS Program,...
# ...

# %%
for tab in table:
    
    print(tab.df,end="/")
# Out:
#                                                     0  \
# 0
# 1                                           Corporate
# 2   Infosys was incorporated in Pune, in 1981, as ...
# 3   Private Limited, a private limited company und...
# 4   Act, 1956. In 1983, the corporate headquarters...
# 5   to Bengaluru. The name of the Company was chan...
# 6   Infosys Technologies Private Limited in April ...
# 7   Technologies Limited in June 1992, when the Co...
# 8
# 9   public limited company. We made an initial pub...
# 10
# 11  in February 1993 and were listed on stock exch...
# 12
# 13  June 1993. Trading opened at ₹145 per share, c...
# 14
# 15  IPO price of ₹95 per share. In October 1994, w...
# 16  placement of 5,50,000 shares at ₹450 each to F...
# 17  Investors (FIIs), Financial Institutions (FIs)...
# 18
# 19  In March 1999, we issued 20,70,000 American De...
# 20
# 21  (ADSs) (equivalent to 10,35,000 equity shares ...
# 22
# 23  each) at US$ 34 per ADS under the ADS Program,...
# ...
