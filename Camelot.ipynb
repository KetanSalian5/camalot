# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import cv2 as cv
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
img=cv.imread('pan.jpg')
img=cv.cvtColor(img,cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (1018, 1700, 3)

# %%
plt.imshow(img)

# %%
res=cv.resize(img,(1000,1000))
res.shape
# Out:
# (1000, 1000, 3)

# %%
text=pytesseract.image_to_string(res)

# %%
print(text)
# Out:
# | aE AT
#
# INOOMETAKDEARIMENT
#
# KETAN NITYANAND SALIAN
#
# ~ NITYANAND PADMA SALIAN
#
# ~ 21/08/1992
# Account Number
#
# FCOPS6858F
#
# bi ,
#
# ANd WaT
#
# GOVT. OF INDIA
#
# 15082013
#
# ‘
#
# _

# %% [markdown]
# ###The sample of the project  is work

# %%
# !pip install PyPDF2
# !pip install PyPDF2[crypto]

# %%
import camelot

# %%
import camelot as cam
import pandas as pd

# %%
tab=camelot.read_pdf("infosys-ar-22.pdf",pages='126',flavor='stream')

# %%
tab
# Out:
# <TableList n=1>

# %%
tab[0].df
# Out:
#                                                     0                 1  \
# 0   transferred to the IEPF on the dates mentioned...
# 1                                                Year  Type of dividend
# 2
# 3                                           2014-2015             Final
# 4                                           2015-2016           Interim
# 5                                           2015-2016             Final
# 6                                           2016-2017           Interim
# 7                                           2016-2017             Final
# 8                                           2017-2018           Interim
# 9                                           2017-2018   Final & Special
# 10                                          2018-2019           Interim
# 11                                          2018-2019           Special
# 12                                          2018-2019             Final
# ...

# %%
tab=camelot.read_pdf("infosys-ar-22.pdf",pages='126',flavor='stream',table_areas=['170,370,560,270'])
tab
# Out:
# <TableList n=1>

# %%
tab[0].df
# Out:
#          0                                      1                 2  \
# 0  Special                                   4.00  January 11, 2019
# 1    Final                                  10.50     June 22, 2019
# 2  Interim                                   8.00  October 11, 2019
# 3    Final                                   9.50     June 27, 2020
# 4  Interim                                  12.00  October 14, 2020
# 5    Final                                  15.00     June 19, 2021
# 6  Interim                                  15.00  October 13, 2021
# 7           Amount unclaimed as on March 31, 2022
#
#                    3            4
# 0  February 10, 2026  1,19,20,004
# 1      July 21, 2026  2,81,47,445
# 2  November 11, 2026  2,40,78,793
# 3      July 28, 2027  2,59,64,031
# 4  November 17, 2027  3,01,37,600
# 5      July 20, 2028  3,43,90,416
# 6  November 16, 2028  3,92,80,980
# 7

# %%
tab=camelot.read_pdf("infosys-ar-22.pdf",pages='126',flavor='stream')

# %%
tab
# Out:
# <TableList n=1>

# %%
camelot.plot(tab[0], kind='grid').show(),-z()

# %%
--help()
# Out:
# Welcome to Python 3.9's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.9/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> -q
# No Python documentation found for '-q'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
